# %%
# %pylab inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
font = {'size'   : 14}
pylab.rc('figure',figsize = (8, 6))
pylab.rc('font',**font)

# %%
import database
from  datetime import datetime, timezone,timedelta

# %%
tz = timezone(timedelta(hours=-4))
sd = datetime(2019,7,26,hour=0,minute=15,tzinfo=tz)
ed = datetime(2019,7,26,hour=7,minute=15,tzinfo=tz)
t = database.EasyThermometry(0,start_date=sd,end_date=ed)

# %%
temps = np.array(t.sensors['GRT'][0])
startnum=0
endnum=-1
plot(temps[startnum:endnum,0],temps[startnum:endnum,1],'.')
print(datetime.fromtimestamp(temps[startnum,0]))
print(datetime.fromtimestamp(temps[endnum,0]))
#print(datetime.fromtimestamp(min(temps[:,0])))
ylim(3.8,4.4)
grid()
# Out:
# 2019-07-27 04:16:12.571000
# 2019-07-27 11:14:25.123000

# %%
temps.shape
# Out:
# (1413, 2)

# %%
tz = timezone(timedelta(hours=-4))
sd = datetime(2019,7,27,hour=0,minute=15,tzinfo=tz)
ed = datetime(2019,7,27,hour=7,minute=15,tzinfo=tz)
t = database.EasyThermometry(0,start_date=sd,end_date=ed)
temps = np.array(t.sensors['GRT'][0])
startnum=0
endnum=-1
plot(temps[startnum:endnum,0],temps[startnum:endnum,1],'.')
print(datetime.fromtimestamp(temps[startnum,0]))
print(datetime.fromtimestamp(temps[endnum,0]))
#print(datetime.fromtimestamp(min(temps[:,0])))
grid()
ylim(3.8,4.4)
# Out:
# 2019-07-27 04:16:12.571000
# 2019-07-27 11:14:25.123000
# (3.8, 4.4)

# %%
tz = timezone(timedelta(hours=-4))
sd = datetime(2019,8,16,hour=11,minute=15,tzinfo=tz)
ed = datetime(2019,8,16,hour=20,minute=15,tzinfo=tz)
t = database.EasyThermometry(0,start_date=sd,end_date=ed)
temps = np.array(t.sensors['GRT'][0])
startnum=0
endnum=-1
plot(temps[startnum:endnum,0],temps[startnum:endnum,1],'.')
print(datetime.fromtimestamp(temps[startnum,0]))
print(datetime.fromtimestamp(temps[endnum,0]))
#print(datetime.fromtimestamp(min(temps[:,0])))
grid()
ylim(3.8,4.4)
# Out:
# 2019-08-16 15:39:17.536000
# 2019-08-17 00:13:25.068000
# (3.8, 4.4)

# %%
tz = timezone(timedelta(hours=-4))
sd = datetime(2019,8,26,hour=0,minute=15,tzinfo=tz)
ed = datetime(2019,8,26,hour=9,minute=15,tzinfo=tz)
t = database.EasyThermometry(0,start_date=sd,end_date=ed)
temps = np.array(t.sensors['GRT'][0])
startnum=0
endnum=-1
plot(temps[startnum:endnum,0],temps[startnum:endnum,1],'.')
print(datetime.fromtimestamp(temps[startnum,0]))
print(datetime.fromtimestamp(temps[endnum,0]))
#print(datetime.fromtimestamp(min(temps[:,0])))
grid()
ylim(3.8,4.4)
# Out:
# 2019-08-26 04:16:37.600000
# 2019-08-26 13:13:08.413000
# (3.8, 4.4)
